# %%
import pandas as pd

# === Heating parameters (1 wt%) ===
heating_params_1_00 = {
    15.0: {'G_p': 0.7898543246061378, 'V': 2.982153424410874, 'alpha': 0.725142265271663, 'Cost': 0.5745987525423442, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 0.7554948096117157, 'V': 2.446226723030748, 'alpha': 0.7099914261312433, 'Cost': 0.7025729763012962, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 0.6974207760035347, 'V': 2.010904981576106, 'alpha': 0.6616160644613094, 'Cost': 1.0871935573179312, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'G_p': 0.637794132352804, 'V': 1.7159659000204583, 'alpha': 0.5793390895179039, 'Cost': 1.3017707693150404, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'G_p': 0.669102107205296, 'V': 1.895562923717084, 'alpha': 0.4776932184557312, 'Cost': 0.7067383728627369, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 24.48743708418503, 'alpha': 0.019784831870906495, 'Cost': 0.23470700341022327, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 104.0528190656575, 'alpha': 0.009958712914148918, 'Cost': 0.2372645832585915, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 298.00898835175167, 'alpha': 0.007862669456066744, 'Cost': 0.7733013251841094, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 546.089284437493, 'alpha': 0.009885430221752431, 'Cost': 0.1818786515567437, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 838.026052560822, 'alpha': 0.010619987838135662, 'Cost': 0.0659916899564356, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 1127.3259639203993, 'alpha': 0.012049591207754786, 'Cost': 0.06002186494626716, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 1435.6586094660233, 'alpha': 0.013801541992150303, 'Cost': 0.062446614807362626, 'Cost Metric': 'RSS', 'Error': None},
    80.0: {'V': 1769.3112011268092, 'alpha': 0.01500524256454881, 'Cost': 0.08439637403718972, 'Cost Metric': 'RSS', 'Error': None}
}

# === Cooling parameters (1 wt%) ===
cooling_params_1_00 = {
    15.0: {'G_p': 1.920650758883433, 'V': 3.1038919521343593, 'alpha': 0.5824117859955765, 'Cost': 0.7906219715047795, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 2.218386734571455, 'V': 3.2713335664208874, 'alpha': 0.5067313066553104, 'Cost': 0.6017526657883772, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 7.858517903234852, 'V': 4.230277242100339, 'alpha': 0.33171544402006925, 'Cost': 0.09501145292331477, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'V': 59.058083915318385, 'alpha': 0.019388778770363328, 'Cost': 0.08049197826422107, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'V': 169.6881209320572, 'alpha': 0.009485809332290355, 'Cost': 0.1698836393439477, 'Cost Metric': 'RSS', 'Error': None},
    40.0: {'V': 328.09937344982455, 'alpha': 0.00832172985768316, 'Cost': 0.486576232715138, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 504.8104235136065, 'alpha': 0.00812955898190507, 'Cost': 0.2990175291987713, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 693.7538957743872, 'alpha': 0.008192451738117166, 'Cost': 0.08160150096310309, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 886.646340152375, 'alpha': 0.007223349903396166, 'Cost': 0.14946826501175037, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 1085.5423707721445, 'alpha': 0.00697702580196922, 'Cost': 0.18338272906301023, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 1286.1554043079443, 'alpha': 0.007924622078599397, 'Cost': 0.1195295812957044, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 1460.6471507686301, 'alpha': 0.00855276473830322, 'Cost': 0.12209032745842073, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 1626.191316393059, 'alpha': 0.010881034487652819, 'Cost': 0.05323001346511141, 'Cost Metric': 'RSS', 'Error': None}
}

# Convert both dictionaries to DataFrames
df_heating_1 = pd.DataFrame.from_dict(heating_params_1, orient='index').reset_index()
df_heating_1.rename(columns={'index': 'Temperature'}, inplace=True)
df_heating_1['Concentration'] = 1.00  # <-- add concentration column

df_cooling_1 = pd.DataFrame.from_dict(cooling_params_1, orient='index').reset_index()
df_cooling_1.rename(columns={'index': 'Temperature'}, inplace=True)
df_cooling_1['Concentration'] = 1.00  # <-- add concentration column

print("🔥 Heating (1 wt%)")
print(df_heating_1.head())

print("\n❄️ Cooling (1 wt%)")
print(df_cooling_1.head())
# Out:
# 🔥 Heating (1 wt%)
#    Temperature       G_p         V     alpha      Cost Cost Metric Error  \
# 0         15.0  0.789854  2.982153  0.725142  0.574599         RSS  None
# 1         20.0  0.755495  2.446227  0.709991  0.702573         RSS  None
# 2         25.0  0.697421  2.010905  0.661616  1.087194         RSS  None
# 3         30.0  0.637794  1.715966  0.579339  1.301771         RSS  None
# 4         35.0  0.669102  1.895563  0.477693  0.706738         RSS  None
#
#    Concentration
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#
# ❄️ Cooling (1 wt%)
#    Temperature       G_p           V     alpha      Cost Cost Metric Error  \
# 0         15.0  1.920651    3.103892  0.582412  0.790622         RSS  None
# 1         20.0  2.218387    3.271334  0.506731  0.601753         RSS  None
# 2         25.0  7.858518    4.230277  0.331715  0.095011         RSS  None
# 3         30.0       NaN   59.058084  0.019389  0.080492         RSS  None
# ...

# %%
import pandas as pd

# === Heating parameters (1.25 wt%) ===
heating_params_1_25 = {
    15.0: {'G_p': 0.16029704617452803, 'V': 5.69767803533102, 'alpha': 0.65465915056395, 'Cost': 0.10246137215746205, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 0.12366822353966399, 'V': 4.577480013586398, 'alpha': 0.6580400649819502, 'Cost': 0.1393036350583723, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 0.32696250318716896, 'V': 3.873760702853766, 'alpha': 0.6625345995064296, 'Cost': 0.0793696038589419, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'G_p': 0.5823671387999916, 'V': 3.5899666443115286, 'alpha': 0.6464822521482938, 'Cost': 0.10822469569525628, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'G_p': 0.8742036395597125, 'V': 4.004507655525221, 'alpha': 0.4959876736025904, 'Cost': 0.04781591744892597, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 57.20826163448337, 'alpha': 0.015662293521484055, 'Cost': 0.16884112489888986, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 215.65638981301976, 'alpha': 0.00838371241341714, 'Cost': 0.13537656979896542, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 482.121677813805, 'alpha': 0.007182990369449956, 'Cost': 0.5457072287450648, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 805.8347300505554, 'alpha': 0.008435987347186497, 'Cost': 0.16480124557394626, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 1235.9218487276737, 'alpha': 0.009294439221171043, 'Cost': 0.0679541001810849, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 1680.352223098914, 'alpha': 0.010005070261769581, 'Cost': 0.0960914163471969, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 2157.42663455809, 'alpha': 0.011369669419645186, 'Cost': 0.1115123746523894, 'Cost Metric': 'RSS', 'Error': None},
    80.0: {'V': 2679.7899332799398, 'alpha': 0.012275984563045296, 'Cost': 0.19365323061240428, 'Cost Metric': 'RSS', 'Error': None}
}

# === Cooling parameters (1.25 wt%) ===
cooling_params_1_25 = {
    15.0: {'G_p': 0.8560077572437731, 'V': 5.78148103025997, 'alpha': 0.6546645773841857, 'Cost': 0.044376299928878156, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 1.164947406957118, 'V': 6.169595993609115, 'alpha': 0.521322412131858, 'Cost': 0.06583230502400857, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 10.436766036734408, 'V': 7.179688596756349, 'alpha': 0.37725885878191223, 'Cost': 0.009976567986087695, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'V': 76.15274088663763, 'alpha': 0.022195649654373133, 'Cost': 0.048598471900599044, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'V': 225.8770768291098, 'alpha': 0.009235936516659679, 'Cost': 0.1179416739571084, 'Cost Metric': 'RSS', 'Error': None},
    40.0: {'V': 453.64106083698687, 'alpha': 0.008496095242098264, 'Cost': 0.644361262420859, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 725.7686075307778, 'alpha': 0.010028649582100046, 'Cost': 0.2494002812411808, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 1016.2427616004815, 'alpha': 0.009354343736278196, 'Cost': 0.03005159047216918, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 1328.8836355081035, 'alpha': 0.008546705451742636, 'Cost': 0.05320371261482793, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 1647.428057779308, 'alpha': 0.007750258816339703, 'Cost': 0.11496504486153687, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 1953.8520273321658, 'alpha': 0.007579489709750103, 'Cost': 0.1531051144075979, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 2225.6444532603196, 'alpha': 0.007737941722220211, 'Cost': 0.20049979655449296, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 2465.23972741656, 'alpha': 0.008874860084421881, 'Cost': 0.17986437884793582, 'Cost Metric': 'RSS', 'Error': None}
}

# Convert both dictionaries to DataFrames
df_heating_1_25 = pd.DataFrame.from_dict(heating_params_1_25, orient='index').reset_index()
df_heating_1_25.rename(columns={'index': 'Temperature'}, inplace=True)
df_heating_1_25['Concentration'] = 1.25

df_cooling_1_25 = pd.DataFrame.from_dict(cooling_params_1_25, orient='index').reset_index()
df_cooling_1_25.rename(columns={'index': 'Temperature'}, inplace=True)
df_cooling_1_25['Concentration'] = 1.25

print("🔥 Heating (1.25 wt%)")
print(df_heating_1_25.head())

print("\n❄️ Cooling (1.25 wt%)")
print(df_cooling_1_25.head())
# Out:
# 🔥 Heating (1.25 wt%)
#    Temperature       G_p         V     alpha      Cost Cost Metric Error  \
# 0         15.0  0.160297  5.697678  0.654659  0.102461         RSS  None
# 1         20.0  0.123668  4.577480  0.658040  0.139304         RSS  None
# 2         25.0  0.326963  3.873761  0.662535  0.079370         RSS  None
# 3         30.0  0.582367  3.589967  0.646482  0.108225         RSS  None
# 4         35.0  0.874204  4.004508  0.495988  0.047816         RSS  None
#
#    Concentration
# 0           1.25
# 1           1.25
# 2           1.25
# 3           1.25
# 4           1.25
#
# ❄️ Cooling (1.25 wt%)
#    Temperature        G_p           V     alpha      Cost Cost Metric Error  \
# 0         15.0   0.856008    5.781481  0.654665  0.044376         RSS  None
# 1         20.0   1.164947    6.169596  0.521322  0.065832         RSS  None
# 2         25.0  10.436766    7.179689  0.377259  0.009977         RSS  None
# ...

# %%
import pandas as pd

# === Heating parameters (1.50 wt%) ===
heating_params_1_50 = {
    15.0: {'G_p': 0.4558836147253034, 'V': 12.117507959716775, 'alpha': 0.6680262804463846, 'Cost': 0.09053239031548804, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 0.47249740140223423, 'V': 10.32695039207918, 'alpha': 0.6767748681356525, 'Cost': 0.09293780111908395, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 0.6500000006810772, 'V': 9.137826087424228, 'alpha': 0.7178617473666621, 'Cost': 0.1667853782340573, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'G_p': 0.5917486511933774, 'V': 8.171755458296266, 'alpha': 0.6269940579588903, 'Cost': 0.0776567769879247, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'G_p': 3.358059501931941, 'V': 9.28535227630843, 'alpha': 0.500681587599196, 'Cost': 0.0256662901508909, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 119.97614645979768, 'alpha': 0.015009176398028451, 'Cost': 0.10743489351854216, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 382.6568111609545, 'alpha': 0.00861636081774713, 'Cost': 0.1544420205252438, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 780.6564678575487, 'alpha': 0.007352062054332301, 'Cost': 0.47292159024846825, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 1250.2622395065043, 'alpha': 0.0077715695132181736, 'Cost': 0.289004589352912, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 1899.6261439830373, 'alpha': 0.008702159692736331, 'Cost': 0.16505693892532425, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 2561.068641537842, 'alpha': 0.009478883951773397, 'Cost': 0.18371957041842943, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 3282.3055539071383, 'alpha': 0.010357816974708972, 'Cost': 0.22538133176018152, 'Cost Metric': 'RSS', 'Error': None},
    80.0: {'V': 4107.378034069673, 'alpha': 0.012164759164653939, 'Cost': 0.21683463061418506, 'Cost Metric': 'RSS', 'Error': None}
}

# === Cooling parameters (1.50 wt%) ===
cooling_params_1_50 = {
    15.0: {'G_p': 2.027847513043677, 'V': 13.615015915907756, 'alpha': 0.5911038796904716, 'Cost': 0.18937818285853383, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 2.8243136188504483, 'V': 15.028610876843883, 'alpha': 0.469746731427282, 'Cost': 0.05905288519234307, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 23.110061242403166, 'V': 16.535012779731257, 'alpha': 0.3362618594933569, 'Cost': 0.011296206710670583, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'V': 139.44489345167054, 'alpha': 0.022963109607285866, 'Cost': 0.031961228722509866, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'V': 382.2291716762056, 'alpha': 0.010941399153857844, 'Cost': 0.1541784847093851, 'Cost Metric': 'RSS', 'Error': None},
    40.0: {'V': 736.0014797222332, 'alpha': 0.010696253711170672, 'Cost': 0.44884574998336274, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 1150.8146219330147, 'alpha': 0.011011342380364657, 'Cost': 0.124794749232155, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 1602.2647023080367, 'alpha': 0.01048746305451981, 'Cost': 0.06981817525984012, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 2072.3023869219305, 'alpha': 0.009551875196288372, 'Cost': 0.09953784042592015, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 2544.8304382711103, 'alpha': 0.009039923069714415, 'Cost': 0.1388376010133588, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 2990.5483669880446, 'alpha': 0.008739762966183557, 'Cost': 0.182466492259635, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 3383.112594585101, 'alpha': 0.008786692533905594, 'Cost': 0.20478416815512715, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 3730.3306237291617, 'alpha': 0.009335538052823736, 'Cost': 0.21148116322403046, 'Cost Metric': 'RSS', 'Error': None}
}

# Convert both dictionaries to DataFrames
df_heating_1_50 = pd.DataFrame.from_dict(heating_params_1_50, orient='index').reset_index()
df_heating_1_50.rename(columns={'index': 'Temperature'}, inplace=True)
df_heating_1_50['Concentration'] = 1.50

df_cooling_1_50 = pd.DataFrame.from_dict(cooling_params_1_50, orient='index').reset_index()
df_cooling_1_50.rename(columns={'index': 'Temperature'}, inplace=True)
df_cooling_1_50['Concentration'] = 1.50

print("🔥 Heating (1.50 wt%)")
print(df_heating_1_50.head())

print("\n❄️ Cooling (1.50 wt%)")
print(df_cooling_1_50.head())
# Out:
# 🔥 Heating (1.50 wt%)
#    Temperature       G_p          V     alpha      Cost Cost Metric Error  \
# 0         15.0  0.455884  12.117508  0.668026  0.090532         RSS  None
# 1         20.0  0.472497  10.326950  0.676775  0.092938         RSS  None
# 2         25.0  0.650000   9.137826  0.717862  0.166785         RSS  None
# 3         30.0  0.591749   8.171755  0.626994  0.077657         RSS  None
# 4         35.0  3.358060   9.285352  0.500682  0.025666         RSS  None
#
#    Concentration
# 0            1.5
# 1            1.5
# 2            1.5
# 3            1.5
# 4            1.5
#
# ❄️ Cooling (1.50 wt%)
#    Temperature        G_p           V     alpha      Cost Cost Metric Error  \
# 0         15.0   2.027848   13.615016  0.591104  0.189378         RSS  None
# 1         20.0   2.824314   15.028611  0.469747  0.059053         RSS  None
# 2         25.0  23.110061   16.535013  0.336262  0.011296         RSS  None
# ...

# %%
import pandas as pd

# === Heating parameters (1.75 wt%) ===
heating_params_1_75 = {
    15.0: {'G_p': 0.08550483739359171, 'V': 21.93992822628055, 'alpha': 0.6005651272406891, 'Cost': 0.05548516367230031, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 0.0016852000360812083, 'V': 19.065642050512217, 'alpha': 0.6372639591966115, 'Cost': 0.08224064114068974, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 0.001534300052213963, 'V': 16.935223527010532, 'alpha': 0.6199421029576715, 'Cost': 0.07412542123991568, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'G_p': 0.21904047255771036, 'V': 16.116782344340734, 'alpha': 0.5463775408367489, 'Cost': 0.020603194869961722, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'G_p': 6.913499583221912, 'V': 17.93544647912166, 'alpha': 0.4516628347853595, 'Cost': 0.016222737315506625, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 184.47087003673244, 'alpha': 0.01722332554825919, 'Cost': 0.0854856595724964, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 553.8072992291434, 'alpha': 0.008924753438484775, 'Cost': 0.11596362474585627, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 1059.5671777529533, 'alpha': 0.006945750451136627, 'Cost': 0.544324297058951, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 1735.0278045951889, 'alpha': 0.007897349623932147, 'Cost': 0.24491571385618616, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 2612.0954149373356, 'alpha': 0.008266261599253193, 'Cost': 0.22501904552084342, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 3534.9619954949226, 'alpha': 0.008700122947351641, 'Cost': 0.3159243976422065, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 4550.49060544232, 'alpha': 0.010251120098716903, 'Cost': 0.2719909239206184, 'Cost Metric': 'RSS', 'Error': None},
    80.0: {'V': 5763.166485316395, 'alpha': 0.011814527516492365, 'Cost': 0.2839759914538463, 'Cost Metric': 'RSS', 'Error': None}
}

# === Cooling parameters (1.75 wt%) ===
cooling_params_1_75 = {
    15.0: {'G_p': 0.575705859268331, 'V': 24.27175715086653, 'alpha': 0.542610902480951, 'Cost': 0.021456521009574812, 'Cost Metric': 'RSS', 'Error': None},
    20.0: {'G_p': 2.4629105373305262, 'V': 27.217732116275357, 'alpha': 0.4306143118237811, 'Cost': 0.021471697881549734, 'Cost Metric': 'RSS', 'Error': None},
    25.0: {'G_p': 28.86600151062467, 'V': 29.580817425727282, 'alpha': 0.31724698451497074, 'Cost': 0.008926394146355675, 'Cost Metric': 'RSS', 'Error': None},
    30.0: {'V': 164.50205221983398, 'alpha': 0.03327453614742849, 'Cost': 0.05478667394723112, 'Cost Metric': 'RSS', 'Error': None},
    35.0: {'V': 453.8238623010085, 'alpha': 0.012200266830892773, 'Cost': 0.13982355677230926, 'Cost Metric': 'RSS', 'Error': None},
    40.0: {'V': 925.7121681753418, 'alpha': 0.01045530472693647, 'Cost': 0.528777788083316, 'Cost Metric': 'RSS', 'Error': None},
    45.0: {'V': 1494.5388107607375, 'alpha': 0.011342990994272157, 'Cost': 0.1042699908111144, 'Cost Metric': 'RSS', 'Error': None},
    50.0: {'V': 2123.6427047127504, 'alpha': 0.010447233334747022, 'Cost': 0.04028147148615531, 'Cost Metric': 'RSS', 'Error': None},
    55.0: {'V': 2801.9805437461523, 'alpha': 0.009261344245751608, 'Cost': 0.07240203876311585, 'Cost Metric': 'RSS', 'Error': None},
    60.0: {'V': 3495.6904767013157, 'alpha': 0.00840075232855126, 'Cost': 0.1600013469768088, 'Cost Metric': 'RSS', 'Error': None},
    65.0: {'V': 4168.0898013928145, 'alpha': 0.008240132301264651, 'Cost': 0.18468302883643065, 'Cost Metric': 'RSS', 'Error': None},
    70.0: {'V': 4758.61791534692, 'alpha': 0.008215275073708443, 'Cost': 0.2455165552738818, 'Cost Metric': 'RSS', 'Error': None},
    75.0: {'V': 5280.297054041234, 'alpha': 0.008924974488589121, 'Cost': 0.23479773532974016, 'Cost Metric': 'RSS', 'Error': None}
}

# Convert both dictionaries to DataFrames
df_heating_1_75 = pd.DataFrame.from_dict(heating_params_1_75, orient='index').reset_index()
df_heating_1_75.rename(columns={'index': 'Temperature'}, inplace=True)
df_heating_1_75['Concentration'] = 1.75

df_cooling_1_75 = pd.DataFrame.from_dict(cooling_params_1_75, orient='index').reset_index()
df_cooling_1_75.rename(columns={'index': 'Temperature'}, inplace=True)
df_cooling_1_75['Concentration'] = 1.75

print("🔥 Heating (1.75 wt%)")
print(df_heating_1_75.head())

print("\n❄️ Cooling (1.75 wt%)")
print(df_cooling_1_75.head())
# Out:
# 🔥 Heating (1.75 wt%)
#    Temperature       G_p          V     alpha      Cost Cost Metric Error  \
# 0         15.0  0.085505  21.939928  0.600565  0.055485         RSS  None
# 1         20.0  0.001685  19.065642  0.637264  0.082241         RSS  None
# 2         25.0  0.001534  16.935224  0.619942  0.074125         RSS  None
# 3         30.0  0.219040  16.116782  0.546378  0.020603         RSS  None
# 4         35.0  6.913500  17.935446  0.451663  0.016223         RSS  None
#
#    Concentration
# 0           1.75
# 1           1.75
# 2           1.75
# 3           1.75
# 4           1.75
#
# ❄️ Cooling (1.75 wt%)
#    Temperature        G_p           V     alpha      Cost Cost Metric Error  \
# 0         15.0   0.575706   24.271757  0.542611  0.021457         RSS  None
# 1         20.0   2.462911   27.217732  0.430614  0.021472         RSS  None
# 2         25.0  28.866002   29.580817  0.317247  0.008926         RSS  None
# ...

# %%
import pandas as pd

# --- Prepare dictionaries for all concentrations ---
# Already collected heating parameters for each concentration
heating_dicts = {
    1.00: heating_params_1_00,
    1.25: heating_params_1_25,
    1.50: heating_params_1_50,
    1.75: heating_params_1_75,
    2.00: {
        15.0: {'G_p': 0.0031325000000108722, 'V': 33.14207802895775, 'alpha': 0.6146992963220492, 'Cost': 0.09612373385201237, 'Cost Metric': 'RSS', 'Error': None},
        20.0: {'G_p': 0.0026645000746882506, 'V': 28.619484091595247, 'alpha': 0.6161847865137609, 'Cost': 0.08029508823303767, 'Cost Metric': 'RSS', 'Error': None},
        25.0: {'G_p': 0.0024672000593494075, 'V': 25.456801084894693, 'alpha': 0.590610742730448, 'Cost': 0.048338149915169666, 'Cost Metric': 'RSS', 'Error': None},
        30.0: {'G_p': 0.6536141399637425, 'V': 25.86162038204246, 'alpha': 0.5085145202450859, 'Cost': 0.02221503705839277, 'Cost Metric': 'RSS', 'Error': None},
        35.0: {'G_p': 16.050870584484525, 'V': 29.298333566587367, 'alpha': 0.4157062513250255, 'Cost': 0.014987699085968273, 'Cost Metric': 'RSS', 'Error': None},
        45.0: {'V': 297.0498599147605, 'alpha': 0.014666245496374786, 'Cost': 0.11121393535732121, 'Cost Metric': 'RSS', 'Error': None},
        50.0: {'V': 806.1737037530652, 'alpha': 0.007636457376574323, 'Cost': 0.14634842110230936, 'Cost Metric': 'RSS', 'Error': None},
        55.0: {'V': 1451.0413612187017, 'alpha': 0.005974445543935174, 'Cost': 0.6480194277792888, 'Cost Metric': 'RSS', 'Error': None},
        60.0: {'V': 2286.9240858958697, 'alpha': 0.007432306038411132, 'Cost': 0.4006498185511236, 'Cost Metric': 'RSS', 'Error': None},
        65.0: {'V': 3412.3462456579027, 'alpha': 0.008793676889599835, 'Cost': 0.14190108960227896, 'Cost Metric': 'RSS', 'Error': None},
        70.0: {'V': 4572.723540440331, 'alpha': 0.009978152279618019, 'Cost': 0.10561489256678294, 'Cost Metric': 'RSS', 'Error': None},
        75.0: {'V': 5790.468099268372, 'alpha': 0.011227533971127216, 'Cost': 0.13025240238637756, 'Cost Metric': 'RSS', 'Error': None},
        80.0: {'V': 7074.686620851624, 'alpha': 0.011916244303706802, 'Cost': 0.2659420022752821, 'Cost Metric': 'RSS', 'Error': None}
    }
}

# Same for cooling parameters
cooling_dicts = {
    1.00: cooling_params_1_00,
    1.25: cooling_params_1_25,
    1.50: cooling_params_1_50,
    1.75: cooling_params_1_75,
    2.00: {
        15.0: {'G_p': 0.004183000004423103, 'V': 35.75442180978014, 'alpha': 0.5296542592701803, 'Cost': 0.03571231900418841, 'Cost Metric': 'RSS', 'Error': None},
        20.0: {'G_p': 5.117199418333356, 'V': 42.12934826980331, 'alpha': 0.39437348214121554, 'Cost': 0.009182653976928606, 'Cost Metric': 'RSS', 'Error': None},
        25.0: {'G_p': 52.18143656155675, 'V': 43.64883377038259, 'alpha': 0.29919951002053774, 'Cost': 0.005805790115547695, 'Cost Metric': 'RSS', 'Error': None},
        30.0: {'V': 251.989002952561, 'alpha': 0.02733425858988, 'Cost': 0.05709324306033678, 'Cost Metric': 'RSS', 'Error': None},
        35.0: {'V': 647.4134428167943, 'alpha': 0.00902023423354389, 'Cost': 0.08543151485963192, 'Cost Metric': 'RSS', 'Error': None},
        40.0: {'V': 1253.2757388070506, 'alpha': 0.006616614505100742, 'Cost': 0.3529354399511666, 'Cost Metric': 'RSS', 'Error': None},
        45.0: {'V': 1975.2365512982262, 'alpha': 0.00684802027611494, 'Cost': 0.27216578277857617, 'Cost Metric': 'RSS', 'Error': None},
        50.0: {'V': 2765.8422265979043, 'alpha': 0.006963481369903646, 'Cost': 0.09057105015452241, 'Cost Metric': 'RSS', 'Error': None},
        55.0: {'V': 3611.9732556952545, 'alpha': 0.006982407052728037, 'Cost': 0.07958039604059856, 'Cost Metric': 'RSS', 'Error': None},
        60.0: {'V': 4473.495445393718, 'alpha': 0.006967361753279226, 'Cost': 0.12729138217001132, 'Cost Metric': 'RSS', 'Error': None},
        65.0: {'V': 5307.037772016257, 'alpha': 0.007444385460566418, 'Cost': 0.11243112985631071, 'Cost Metric': 'RSS', 'Error': None},
        70.0: {'V': 6036.6616804637415, 'alpha': 0.00803819584650751, 'Cost': 0.11822337701056342, 'Cost Metric': 'RSS', 'Error': None},
        75.0: {'V': 6645.858386695008, 'alpha': 0.009418773940195455, 'Cost': 0.11072931579886007, 'Cost Metric': 'RSS', 'Error': None}
    }
}

# --- Function to convert dicts to DataFrame ---
def dicts_to_df(all_dicts):
    df_list = []
    for conc, temp_dict in all_dicts.items():
        df_temp = pd.DataFrame.from_dict(temp_dict, orient='index').reset_index()
        df_temp.rename(columns={'index': 'Temperature'}, inplace=True)
        df_temp['Concentration'] = conc
        df_list.append(df_temp)
    return pd.concat(df_list, ignore_index=True)

# --- Create master DataFrames ---
df_heating_all = dicts_to_df(heating_dicts)
df_cooling_all = dicts_to_df(cooling_dicts)

# Check
print("🔥 Heating Master DataFrame:")
print(df_heating_all.head(10))

print("\n❄️ Cooling Master DataFrame:")
print(df_cooling_all.head(10))
# Out:
# 🔥 Heating Master DataFrame:
#    Temperature       G_p           V     alpha      Cost Cost Metric Error  \
# 0         15.0  0.789854    2.982153  0.725142  0.574599         RSS  None
# 1         20.0  0.755495    2.446227  0.709991  0.702573         RSS  None
# 2         25.0  0.697421    2.010905  0.661616  1.087194         RSS  None
# 3         30.0  0.637794    1.715966  0.579339  1.301771         RSS  None
# 4         35.0  0.669102    1.895563  0.477693  0.706738         RSS  None
# 5         45.0       NaN   24.487437  0.019785  0.234707         RSS  None
# 6         50.0       NaN  104.052819  0.009959  0.237265         RSS  None
# 7         55.0       NaN  298.008988  0.007863  0.773301         RSS  None
# 8         60.0       NaN  546.089284  0.009885  0.181879         RSS  None
# 9         65.0       NaN  838.026053  0.010620  0.065992         RSS  None
#
#    Concentration
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np

plt.style.use(['science', 'nature', 'bright'])

# Figure
plt.figure(figsize=(2.33, 2.2))
ax = plt.gca()

# Colors from tab20c
cmap = plt.get_cmap('tab20c')
concentrations = sorted(df_heating_all['Concentration'].unique())
n_colors = len(concentrations)
colors = [cmap(i / n_colors) for i in range(n_colors)]

for i, conc in enumerate(concentrations):
    color = colors[i]
    
    # Heating: solid circles
    df_h = df_heating_all[df_heating_all['Concentration'] == conc].dropna(subset=['G_p'])
    if not df_h.empty:
        ax.plot(df_h['Temperature'], df_h['G_p'], linestyle='none', marker='o',
                markersize=6, color=color, label=f'{conc:.2f}%')
    
    # Cooling: empty circles
    df_c = df_cooling_all[df_cooling_all['Concentration'] == conc].dropna(subset=['G_p'])
    if not df_c.empty:
        ax.plot(df_c['Temperature'], df_c['G_p'], linestyle='none', marker='o',
                markersize=6, mfc='none', mec=color)

# Legend for concentrations
ax.legend(title='$C$ [wt\%]', fontsize=8, frameon=False)

# Labels and style
ax.set_yscale('linear')
ax.set_xlabel('$T$ [°C]', fontsize=9)
ax.set_ylabel('$G_e$ [Pa]', fontsize=9)
ax.tick_params(axis='both', which='both', direction='in', labelsize=9)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np

plt.style.use(['science', 'nature', 'bright'])

# Figure
plt.figure(figsize=(2.33, 2.2))
ax = plt.gca()

# Colors from tab20c
cmap = plt.get_cmap('tab20c')
concentrations = sorted(df_heating_all['Concentration'].unique())
n_colors = len(concentrations)
colors = [cmap(i / n_colors) for i in range(n_colors)]

for i, conc in enumerate(concentrations):
    color = colors[i]
    
    # Heating: solid circles
    df_h = df_heating_all[df_heating_all['Concentration'] == conc].dropna(subset=['G_p'])
    if not df_h.empty:
        tau_h = (df_h['V'] / df_h['G_p']) ** (1 / df_h['alpha'])
        ax.plot(df_h['Temperature'], tau_h, linestyle='none', marker='o',
                markersize=6, color=color, label=f'{conc:.2f}%')
    
    # Cooling: empty circles
    df_c = df_cooling_all[df_cooling_all['Concentration'] == conc].dropna(subset=['G_p'])
    if not df_c.empty:
        tau_c = (df_c['V'] / df_c['G_p']) ** (1 / df_c['alpha'])
        ax.plot(df_c['Temperature'], tau_c, linestyle='none', marker='o',
                markersize=6, mfc='none', mec=color)

# Legend for concentrations
ax.legend(title='$C$ [wt\%]', fontsize=8, frameon=False)

# Labels and style
ax.set_yscale('linear')
ax.set_xlabel('$T$ [°C]', fontsize=9)
ax.set_ylabel(r'$\tau~[\mathrm{s}]$', fontsize=9)
ax.tick_params(axis='both', which='both', direction='in', labelsize=9)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LogLocator

plt.style.use(['science', 'nature', 'bright'])

# Unique concentrations
concentrations = sorted(df_heating_all['Concentration'].unique())
n_conc = len(concentrations)

# Colors from tab20c
cmap = plt.get_cmap('tab20c')
colors = [cmap(i / n_conc) for i in range(n_conc)]

# Create subplots (rows of 2 or 3)
ncols = 3
nrows = int(np.ceil(n_conc / ncols))
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(7, 5), sharey=True)
axes = axes.flatten()

for i, conc in enumerate(concentrations):
    ax = axes[i]
    color = colors[i]
    
    # Heating
    df_h = df_heating_all[df_heating_all['Concentration'] == conc].dropna(subset=['G_p'])
    if not df_h.empty:
        tau_h = (df_h['V'] / df_h['G_p']) ** (1 / df_h['alpha'])
        ax.plot(df_h['Temperature'], tau_h, linestyle='none', marker='o',
                markersize=6, color=color, label='heating')
    
    # Cooling
    df_c = df_cooling_all[df_cooling_all['Concentration'] == conc].dropna(subset=['G_p'])
    if not df_c.empty:
        tau_c = (df_c['V'] / df_c['G_p']) ** (1 / df_c['alpha'])
        ax.plot(df_c['Temperature'], tau_c, linestyle='none', marker='o',
                markersize=6, mfc='none', mec=color, label='cooling')
    
    ax.set_title(f'{conc:.2f}% concentration', fontsize=10)
    ax.set_yscale('log')
    
    # Show all 10^ticks
    ax.yaxis.set_major_locator(LogLocator(base=10.0, subs=np.arange(1, 10)*0.1, numticks=10))
    
    ax.set_xlabel('$T$ [°C]', fontsize=9)
    ax.set_ylabel(r'$\tau_c$ [s]', fontsize=9)
    ax.tick_params(axis='both', which='both', direction='in', labelsize=9)
    ax.legend(frameon=True, fontsize=8)

# Remove empty subplots if any
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LogLocator

plt.style.use(['science', 'nature', 'bright'])

# Unique temperatures
temperatures = sorted(df_heating_all['Temperature'].unique())
n_temps = len(temperatures)

# Colors for each temperature
cmap = plt.get_cmap('tab20')
colors = [cmap(i / n_temps) for i in range(n_temps)]

# Figure
plt.figure(figsize=(6, 4))
ax = plt.gca()

# Loop over temperatures
for i, temp in enumerate(temperatures):
    color = colors[i]
    
    # Heating: solid circles
    df_h_temp = df_heating_all[df_heating_all['Temperature'] == temp].dropna(subset=['G_p'])
    if not df_h_temp.empty:
        tau_h = (df_h_temp['V'] / df_h_temp['G_p']) ** (1 / df_h_temp['alpha'])
        ax.plot(df_h_temp['Concentration'], tau_h, linestyle='none', marker='o',
                markersize=6, color=color, label=f'{temp}°C heating')
    
    # Cooling: empty circles
    df_c_temp = df_cooling_all[df_cooling_all['Temperature'] == temp].dropna(subset=['G_p'])
    if not df_c_temp.empty:
        tau_c = (df_c_temp['V'] / df_c_temp['G_p']) ** (1 / df_c_temp['alpha'])
        #ax.plot(df_c_temp['Concentration'], tau_c, linestyle='none', marker='o',
        #        markersize=6, mfc='none', mec=color, label=f'{temp}°C cooling')

# Log scale for y
ax.set_yscale('log')
#ax.yaxis.set_major_locator(LogLocator(base=10.0, subs=np.arange(1, 10)*0.1, numticks=10))

ax.set_xlabel('Concentration [wt%]', fontsize=10)
ax.set_ylabel(r'$\tau_c$ [s]', fontsize=10)
ax.tick_params(axis='both', which='both', direction='in', labelsize=9)
ax.legend(frameon=True, fontsize=8, ncol=2)

plt.tight_layout()
plt.show()
